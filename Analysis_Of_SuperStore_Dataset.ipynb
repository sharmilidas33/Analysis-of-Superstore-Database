# %% [markdown]
# # ***Importing Libraries and the Superstore Dataset***

# %%
#importing libraries pandas and numpy
import pandas as pd
import numpy as np

# %%
#importing the dataset
dataset = pd.read_csv("/content/Sample - Superstore.csv",encoding='windows-1254')
dataset.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
#shape of the dataset
dataset.shape
# Out:
# (9994, 21)

# %% [markdown]
# # ***Checking Datatype and Missing or Duplicate Values***

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
dataset.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
#checking for missing/null values
dataset.isna().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %% [markdown]
# Showing all zeros, that means there are no missing values.

# %%
#checking for duplicate values
dataset.duplicated().sum()
# Out:
# 0

# %% [markdown]
# 0 means no duplicate values found and 1 means there are duplicate values.

# %% [markdown]
# # ***Statistical Information about the Distribution of Data***

# %%
dataset.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
dataset.corr()
# Out:
# <ipython-input-77-c187c74d1e71>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataset.corr()
#                Row ID  Postal Code     Sales  Quantity  Discount    Profit
# Row ID       1.000000     0.009671 -0.001359 -0.004016  0.013480  0.012497
# Postal Code  0.009671     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales       -0.001359    -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity    -0.004016     0.012761  0.200795  1.000000  0.008623  0.066253
# Discount     0.013480     0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit       0.012497    -0.029961  0.479064  0.066253 -0.219487  1.000000

# %% [markdown]
# # ***Reading the Categorical Features***

# %%
df_cat = dataset[[ 'Ship Mode', 'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State', 'Region',
                  'Product ID', 'Category', 'Sub-Category', 'Product Name']]

# %%
df_cat.head()
# Out:
#         Ship Mode Customer ID    Customer Name    Segment        Country  \
# 0    Second Class    CG-12520      Claire Gute   Consumer  United States
# 1    Second Class    CG-12520      Claire Gute   Consumer  United States
# 2    Second Class    DV-13045  Darrin Van Huff  Corporate  United States
# 3  Standard Class    SO-20335   Sean O'Donnell   Consumer  United States
# 4  Standard Class    SO-20335   Sean O'Donnell   Consumer  United States
#
#               City       State Region       Product ID         Category  \
# 0        Henderson    Kentucky  South  FUR-BO-10001798        Furniture
# 1        Henderson    Kentucky  South  FUR-CH-10000454        Furniture
# 2      Los Angeles  California   West  OFF-LA-10000240  Office Supplies
# 3  Fort Lauderdale     Florida  South  FUR-TA-10000577        Furniture
# 4  Fort Lauderdale     Florida  South  OFF-ST-10000760  Office Supplies
#
#   Sub-Category                                       Product Name
# ...

# %% [markdown]
# # ***Exploratory Data Analysis - EDA***

# %%
#reading number of unique values in categorical data
for feature in df_cat.columns:
  print(feature, ":", dataset[feature].nunique())
# Out:
# Ship Mode : 4
# Customer ID : 793
# Customer Name : 793
# Segment : 3
# Country : 1
# City : 531
# State : 49
# Region : 4
# Product ID : 1862
# Category : 3
# Sub-Category : 17
# Product Name : 1850

# %%
#pinting names of unique cities
dataset["City"].unique()
# Out:
# array(['Henderson', 'Los Angeles', 'Fort Lauderdale', 'Concord',
#        'Seattle', 'Fort Worth', 'Madison', 'West Jordan', 'San Francisco',
#        'Fremont', 'Philadelphia', 'Orem', 'Houston', 'Richardson',
#        'Naperville', 'Melbourne', 'Eagan', 'Westland', 'Dover',
#        'New Albany', 'New York City', 'Troy', 'Chicago', 'Gilbert',
#        'Springfield', 'Jackson', 'Memphis', 'Decatur', 'Durham',
#        'Columbia', 'Rochester', 'Minneapolis', 'Portland', 'Saint Paul',
#        'Aurora', 'Charlotte', 'Orland Park', 'Urbandale', 'Columbus',
#        'Bristol', 'Wilmington', 'Bloomington', 'Phoenix', 'Roseville',
#        'Independence', 'Pasadena', 'Newark', 'Franklin', 'Scottsdale',
#        'San Jose', 'Edmond', 'Carlsbad', 'San Antonio', 'Monroe',
#        'Fairfield', 'Grand Prairie', 'Redlands', 'Hamilton', 'Westfield',
#        'Akron', 'Denver', 'Dallas', 'Whittier', 'Saginaw', 'Medina',
#        'Dublin', 'Detroit', 'Tampa', 'Santa Clara', 'Lakeville',
# ...

# %%
#printing number of unique order dates
dataset['Order Date'].nunique()
# Out:
# 1237

# %%
#printing number of unique ship dates
dataset['Ship Date'].nunique()
# Out:
# 1334

# %%
#printing first 5 rows
dataset.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
#printing last 5 rows
dataset.tail()
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9989    9990  CA-2014-110422  1/21/2014  1/23/2014    Second Class
# 9990    9991  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9991    9992  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9992    9993  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9993    9994  CA-2017-119914   5/4/2017   5/9/2017    Second Class
#
#      Customer ID     Customer Name   Segment        Country         City  ...  \
# 9989    TB-21400  Tom Boeckenhauer  Consumer  United States        Miami  ...
# 9990    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9991    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9992    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9993    CC-12220      Chris Cortes  Consumer  United States  Westminster  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# # ***Top Selling Products in Superstore***

# %%
#grouping product names along with their total selling costs
product_group = dataset.groupby(["Product Name"]).sum()["Sales"]
product_group.head()
# Out:
# <ipython-input-86-d375ad2d3241>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   product_group = dataset.groupby(["Product Name"]).sum()["Sales"]
# Product Name
# "While you Were Out" Message Book, One Form per Page     25.228
# #10 Gummed Flap White Envelopes, 100/Box                 41.300
# #10 Self-Seal White Envelopes                           108.682
# #10 White Business Envelopes,4 1/8 x 9 1/2              488.904
# #10- 4 1/8" x 9 1/2" Recycled Envelopes                 286.672
# Name: Sales, dtype: float64

# %%
#sorting the total sale of respective products in descending order
top_selling_product = product_group.sort_values(ascending = False)
top_five_selling_products = top_selling_product.head()
top_five_selling_products
# Out:
# Product Name
# Canon imageCLASS 2200 Advanced Copier                                          61599.824
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind    27453.384
# Cisco TelePresence System EX90 Videoconferencing Unit                          22638.480
# HON 5400 Series Task Chairs for Big and Tall                                   21870.576
# GBC DocuBind TL300 Electric Binding System                                     19823.479
# Name: Sales, dtype: float64

# %% [markdown]
# "Canon imageCLASS 2200 Advanced Copier" having a sale of "61599.824" is by far the most selling product.

# %% [markdown]
# # ***Plotting Top 5 Selling Products in Superstore***

# %%
#importing matplotlib and seaborn for plotting
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
top_five_selling_products.plot(kind="bar")
plt.title("Top 5 Selling Products in Superstore")
plt.xlabel("Product Name")
plt.ylabel("Total Sales")
plt.show()

# %% [markdown]
# # ***Plotting Top 5 Profitable Products in Superstore***

# %%
#grouping product names along with their total profits
product_group = dataset.groupby(["Product Name"]).sum()["Profit"]

#sorting the total sale of respective products in descending order
top_profitable_product = product_group.sort_values(ascending = False)
top_five_profitable_products = top_profitable_product.head()
top_five_profitable_products
# Out:
# <ipython-input-90-fbee62de2c10>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   product_group = dataset.groupby(["Product Name"]).sum()["Profit"]
# Product Name
# Canon imageCLASS 2200 Advanced Copier                                          25199.9280
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind     7753.0390
# Hewlett Packard LaserJet 3310 Copier                                            6983.8836
# Canon PC1060 Personal Laser Copier                                              4570.9347
# HP Designjet T520 Inkjet Large Format Printer - 24" Color                       4094.9766
# Name: Profit, dtype: float64

# %%
#plotting
top_five_profitable_products.plot(kind="bar")
plt.title("Top 5 Profitable Products in Superstore")
plt.xlabel("Product Name")
plt.ylabel("Total Profit")
plt.show()

# %% [markdown]
# # ***Are Top Selling Products the Most Profitable?***

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,5))

# Plot the top 5 selling products in the first column
top_five_selling_products.plot(kind="bar", y="Sales", ax=ax1)
ax1.set_title("Top 5 Selling Products")

# Plot the top 5 profitable products in the second column
top_five_profitable_products.plot(kind="bar", y="Profit", ax=ax2)
ax2.set_title("Top 5 Profit Products")

# Show the plot
plt.show()

# %%
top_five_profitable_products.index == top_five_selling_products.index
# Out:
# array([ True,  True, False, False, False])

# %% [markdown]
# # ***Top 5 Most Profitable Cities***

# %%
#grouping cities along with their total profits
profit_cities = dataset.groupby(["City"]).sum()["Profit"]

#sorting the total profits of respective cities in descending order
top_profit_city = profit_cities.sort_values(ascending = False)
top_five_profitable_cities = top_profit_city.head()
top_five_profitable_cities
# Out:
# <ipython-input-124-cd2b56f5fa25>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   profit_cities = dataset.groupby(["City"]).sum()["Profit"]
# City
# New York City    62036.9837
# Los Angeles      30440.7579
# Seattle          29156.0967
# San Francisco    17507.3854
# Detroit          13181.7908
# Name: Profit, dtype: float64

# %% [markdown]
# # ***Top 5 Most Profitable States***

# %%
#grouping states along with their total profits
profit_states = dataset.groupby(["State"]).sum()["Profit"]

#sorting the total profits of respective states in descending order
top_profit_state = profit_states.sort_values(ascending = False)
top_five_profitable_states = top_profit_state.head()
top_five_profitable_states
# Out:
# <ipython-input-95-95365785ba30>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   profit_states = dataset.groupby(["State"]).sum()["Profit"]
# State
# California    76381.3871
# New York      74038.5486
# Washington    33402.6517
# Michigan      24463.1876
# Virginia      18597.9504
# Name: Profit, dtype: float64

# %% [markdown]
# # ***Most Profitable Sub-category***

# %%
#grouping sub-categories along with their total profits
profit_sub_categories = dataset.groupby(["Sub-Category"]).sum()["Profit"]

#sorting the total profits of respective sub-categories in descending order
top_profit_sub_category = profit_sub_categories.sort_values(ascending = False)
top_five_profitable_sub_categories = top_profit_sub_category.head()
top_five_profitable_sub_categories
# Out:
# <ipython-input-96-b0d683d7ce54>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   profit_sub_categories = dataset.groupby(["Sub-Category"]).sum()["Profit"]
# Sub-Category
# Copiers        55617.8249
# Phones         44515.7306
# Accessories    41936.6357
# Paper          34053.5693
# Binders        30221.7633
# Name: Profit, dtype: float64

# %%
#plotting
top_five_profitable_sub_categories.plot(kind="bar")
plt.title("Top 5 Profitable SubCategories in Superstore")
plt.xlabel("Sub-Category")
plt.ylabel("Total Profit")
plt.show()

# %% [markdown]
# # ***Most Selling Category***

# %%
dataset['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
#grouping categories along with their total sales
category_sales = dataset.groupby(["Category"]).sum()["Sales"]

#sorting the total sales of respective categories in descending order
top_category_sales = category_sales.sort_values(ascending = False)

#plotting
top_category_sales.plot(kind="bar")
plt.title("Most Selling Categories in Superstore")
plt.xlabel("Category")
plt.ylabel("Total Sales")
plt.show()
# Out:
# <ipython-input-105-6edc9824fe97>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   category_sales = dataset.groupby(["Category"]).sum()["Sales"]

# %% [markdown]
# # ***Most Profitable Region***

# %%
#grouping regions along with their total profits
profitable_regions = dataset.groupby(["Region"]).sum()["Profit"]

#sorting the total profits of respective regions in descending order
top_profitable_regions = profitable_regions.sort_values(ascending = False)
top_profitable_regions
# Out:
# <ipython-input-107-b58211a91ca0>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   profitable_regions = dataset.groupby(["Region"]).sum()["Profit"]
# Region
# West       108418.4489
# East        91522.7800
# South       46749.4303
# Central     39706.3625
# Name: Profit, dtype: float64

# %% [markdown]
# # ***Sales Trend over Time (Monthly, Yearly)***

# %%
dataset['Order Date'] = pd.to_datetime(dataset['Order Date'])
monthly_sales = dataset.groupby(['Order Date'], as_index=False).sum()

# Set the Order Date column as the index of the dataframe
monthly_sales = monthly_sales.set_index('Order Date')
# Resample the data into monthly intervals
monthly_sales = monthly_sales.resample('M').sum() # M for month

# Plot
plt.figure(figsize=(15,5))
plt.plot(monthly_sales['Sales'])
plt.xlabel("Order Date")
plt.ylabel("Sales")
plt.title("Monthly Sales Trend")
plt.show()
# Out:
# <ipython-input-114-f8b8eb04356b>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   monthly_sales = dataset.groupby(['Order Date'], as_index=False).sum()

# %%
yearly_sales = monthly_sales.resample('Y').sum()
# Plot
plt.figure(figsize=(15,5))
plt.plot(yearly_sales['Sales'])
plt.xlabel("Order Date")
plt.ylabel("Sales")
plt.title("yearly Sales Trend")
plt.show()

# %% [markdown]
# # ***Sales, Profit and Discount Relations***

# %%
# Group the data by the discount and compute the average sales
discount_group = dataset.groupby(["Discount"]).mean()[["Sales"]]
# Convert the discount values to percentages
discount_group.index = discount_group.index.map(lambda x: f"{int(x * 100)}%")

ax = discount_group.plot(kind="bar")
ax.set_ylabel("Sales")
plt.show()
# Out:
# <ipython-input-130-dd3a4239cbb1>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   discount_group = dataset.groupby(["Discount"]).mean()[["Sales"]]

# %% [markdown]
# Sales are the highest, when Discount is of 50%.

# %%
# Group the data by the discount and compute the average profits
discount_group = dataset.groupby(["Discount"]).mean()[["Profit"]]
# Convert the discount values to percentages
discount_group.index = discount_group.index.map(lambda x: f"{int(x * 100)}%")

ax = discount_group.plot(kind="bar")
ax.set_ylabel("Profit")
plt.show()
# Out:
# <ipython-input-131-d0015af4d865>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   discount_group = dataset.groupby(["Discount"]).mean()[["Profit"]]

# %% [markdown]
# Profit is least when Discount is of 50% and highest when Discount is of 10%.

# %% [markdown]
# **Hence, the discount from 10% to 20% is the best solution, as they are great sellers and make good profits.**

# %% [markdown]
# # ***Segment and Ship Mode Relation***

# %%
dataset['Segment'].value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
dataset['Ship Mode'].value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %%
pivot_table = dataset.pivot_table(index='Segment', columns='Ship Mode', values='Sales', aggfunc='sum')
pivot_table
# Out:
# Ship Mode    First Class   Same Day  Second Class  Standard Class
# Segment
# Consumer     159168.9650  60596.359   231498.9496     710137.0714
# Corporate    105858.4699  45121.323   146126.0388     409040.5351
# Home Office   86400.9880  22645.443    81568.5810     239038.1365

# %%
#plotting
pivot_table.plot(kind="bar")
# Out:
# <Axes: xlabel='Segment'>

# %% [markdown]
# # ***Building a Machine Learning Model to Predict the Profit***

# %%
dataset.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %% [markdown]
# **Feature Selection:**

# %%
dataset1 = dataset.drop(columns=["Row ID","Order ID","Order Date","Ship Date","Customer ID","Customer Name","Country","City","State",
                                 "Postal Code","Product ID","Sub-Category","Product Name"])
dataset1.head()
# Out:
#         Ship Mode    Segment Region         Category     Sales  Quantity  \
# 0    Second Class   Consumer  South        Furniture  261.9600         2
# 1    Second Class   Consumer  South        Furniture  731.9400         3
# 2    Second Class  Corporate   West  Office Supplies   14.6200         2
# 3  Standard Class   Consumer  South        Furniture  957.5775         5
# 4  Standard Class   Consumer  South  Office Supplies   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %% [markdown]
# **Label Encoding:**

# %%
print("Ship Mode :", dataset1["Ship Mode"].nunique())
print("Segment :", dataset1["Segment"].nunique())
print("Region :", dataset1["Region"].nunique())
print("Category :", dataset1["Category"].nunique())
# Out:
# Ship Mode : 4
# Segment : 3
# Region : 4
# Category : 3

# %%
#to convert data into numerical data
#to make data more machine readable
#to increase accuracy of the model
dataset1.replace({"Ship Mode" : {"Standard Class":0, "Second Class":1, "First Class":2, "Same Day":3},
                  "Segment":{"Consumer":0, "Corporate":1, "Home Office":2},
                  "Category":{"Office Supplies":0, "Furniture":1, "Technology":2},
                  "Region":{"West":0, "East":1, "Central":2, "South":3}},
                 inplace=True)
dataset1.head()
# Out:
#    Ship Mode  Segment  Region  Category     Sales  Quantity  Discount  \
# 0          1        0       3         1  261.9600         2      0.00
# 1          1        0       3         1  731.9400         3      0.00
# 2          1        1       0         0   14.6200         2      0.00
# 3          0        0       3         1  957.5775         5      0.45
# 4          0        0       3         0   22.3680         2      0.20
#
#      Profit
# 0   41.9136
# 1  219.5820
# 2    6.8714
# 3 -383.0310
# 4    2.5164

# %%
x = dataset1.iloc[:, :-1]
print(x)
# Out:
#       Ship Mode  Segment  Region  Category     Sales  Quantity  Discount
# 0             1        0       3         1  261.9600         2      0.00
# 1             1        0       3         1  731.9400         3      0.00
# 2             1        1       0         0   14.6200         2      0.00
# 3             0        0       3         1  957.5775         5      0.45
# 4             0        0       3         0   22.3680         2      0.20
# ...         ...      ...     ...       ...       ...       ...       ...
# 9989          1        0       3         1   25.2480         3      0.20
# 9990          0        0       0         1   91.9600         2      0.00
# 9991          0        0       0         2  258.5760         2      0.20
# 9992          0        0       0         0   29.6000         4      0.00
# 9993          1        0       0         0  243.1600         2      0.00
#
# [9994 rows x 7 columns]

# %%
y = dataset1.iloc[:, -1]
print(y)
# Out:
# 0        41.9136
# 1       219.5820
# 2         6.8714
# 3      -383.0310
# 4         2.5164
#           ...
# 9989      4.1028
# 9990     15.6332
# 9991     19.3932
# 9992     13.3200
# 9993     72.9480
# Name: Profit, Length: 9994, dtype: float64

# %% [markdown]
# **Re-scaling the Dataset:**

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

num_vars = ["Sales","Quantity"]
x[num_vars] = scaler.fit_transform(x[num_vars])
print(x)
# Out:
#       Ship Mode  Segment  Region  Category     Sales  Quantity  Discount
# 0             1        0       3         1  0.011552  0.076923      0.00
# 1             1        0       3         1  0.032313  0.153846      0.00
# 2             1        1       0         0  0.000626  0.076923      0.00
# 3             0        0       3         1  0.042280  0.307692      0.45
# 4             0        0       3         0  0.000968  0.076923      0.20
# ...         ...      ...     ...       ...       ...       ...       ...
# 9989          1        0       3         1  0.001096  0.153846      0.20
# 9990          0        0       0         1  0.004043  0.076923      0.00
# 9991          0        0       0         2  0.011403  0.076923      0.20
# 9992          0        0       0         0  0.001288  0.230769      0.00
# 9993          1        0       0         0  0.010722  0.076923      0.00
#
# [9994 rows x 7 columns]

# %% [markdown]
# **Splitting the Dataset into Training and Testing Data:**

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x, y, test_size=0.25, random_state=100)

print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
# Out:
# (7495, 7) (2499, 7) (7495,) (2499,)

# %% [markdown]
# **Creating a Machine Learning Model:**

# %%
from sklearn.ensemble import RandomForestRegressor
model=RandomForestRegressor(random_state=0, n_estimators=117)
model.fit(x_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=117, random_state=0)

# %% [markdown]
# **Predicting the Test Data:**

# %%
y_pred = model.predict(x_test)

from sklearn.metrics import r2_score
print("R2 Score=",r2_score(y_pred,y_test)*100)
# Out:
# R2 Score= 74.08625172960967

# %%
#plotting
fig = plt.figure()
plt.scatter(y_test,y_pred)
#plot heading
fig.suptitle('y_test vs y_pred', fontsize=20)
plt.xlabel('y_test', fontsize=18)
plt.ylabel('Y_pred', fontsize=16)
# Out:
# Text(0, 0.5, 'Y_pred')
